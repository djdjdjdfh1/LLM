# %%
# %pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
# client = OpenAI(api_key=os.environ['OPENAI_API_KEY'])
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="2025년 11월 21일 서울과 경기도의 날씨와 22일 23일 날씨를 기상정보를 검색해서 알려줘"
)

print(response.output_text)
# Out:
# 요청하신 날짜의 구체적이고 최신 기상정보는 제가 바로 웹 검색으로 확인해 드릴 수 없어요. 다만 최신 예보를 확인하는 방법과, 확인 후 제가 해석해 드리는 방식으로 도와드리겠습니다.
#
# 어떤 정보를 어디에서 확인하면 좋을지 추천드려요
# - 기상청 공식 사이트(한국 기상청): 전국/지역별 3~7일 예보를 제공. 서울 및 경기도(지역 선택)로 실시간 예보를 확인하기에 가장 신뢰도 높습니다.
#   - 사용 팁: 검색창에 "서울 날씨 예보" 또는 "기상청 서울 오늘의 날씨", 지역으로 경기도의 여러 시군도 조회 가능. 2~3일 단기예보와 주간예보를 확인해 보세요.
# - 주요 포털의 날씨 서비스(네이버 날씨, 다음 날씨, 카카오 날씨 등): 지역별 예보를 한 번에 보기 쉽고, 모바일에서 빠르게 확인하기 좋습니다.
#   - 사용 팁: 검색창에 “서울 날씨 11월 21일”, “경기도 수원 날씨 11월 21일”처럼 날짜를 함께 입력해 보세요.
# - 국제 기상 서비스(AccuWeather, The Weather Channel): 해외 서비스이지만 세부 지역의 예보를 확인하고 차트 형태로 비교하기 좋습니다.
#   - 사용 팁: 같은 지역 이름과 날짜를 함께 조회해 보세요.
#
# 확인 방법 요약
# - 1) 오늘과 가까운 날짜의 예보를 먼저 확인: 21일(오늘)과 22일, 23일의 단기예보를 확인합니다.
# - 2) 서울과 경기도의 동일 기간 예보를 각각 확인합니다(경기도는 시군별 차이가 작게 나타날 때도 있지만, 대체로 서울 근처는 비슷한 흐름일 때가 많습니다).
# - 3) 예보 항목 체크: 날짜별로 최저/최고 기온, 강수확률, 강수 형태(비/눈/빗방울 여부), 바람 방향/세기, 체감온도, 습도.
#
# 제가 도와드릴 수 있는 방법
# - 지금 바로 제가 최신 예보를 조회해 드릴 수는 없지만, 사용 가능한 출처를 알려드리고 링크를 바탕으로 날짜별 요약을 만들어 드릴 수 있습니다.
# - 또는 사용자가 위의 사이트에서 2025-11-21, 11-22, 11-23의 예보를 복사해 주시면, 서울 vs 경기도의 차이, 옷차림 팁, 외출 시 주의사항 등을 한 눈에 비교해 정리해 드리겠습니다.
#
# 추가로 알고 싶으신 것
# - 서울과 경기도 내 특정 지역(예: 서울특별시 종로구, 수원시 권선구 등)으로 한정해 드릴까요? 특정 지역을 알려주시면 그 지역 기준으로 예보를 비교해 정리해 드리겠습니다.
# - 원하시면 제가 일반적인 11월 말의 기후 특성(대략적인 옷차림 팁, 자주 겪는 기상현상 등)도 간단히 요약해 드릴게요.
#
# 원하시는 방식으로 진행해도 될지 알려주시면, 제가 바로 도와드리겠습니다. 도움이 필요하신 구체적인 지역이나 선호하는 사이트가 있으면 함께 알려주세요.
